# %% [markdown]
# ## CNN using frames and RESNET and all 5 emotes

# %% [markdown]
# AI/ CNN HW helped us generate this code - we used similar code for each frame based CNN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/DS340/frames.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/DS340/frames.zip
#    creating: /content/frames/
#   inflating: /content/__MACOSX/._frames
#   inflating: /content/frames/.DS_Store
#   inflating: /content/__MACOSX/frames/._.DS_Store
#    creating: /content/frames/test/
#   inflating: /content/__MACOSX/frames/._test
#    creating: /content/frames/original_frames/
#   inflating: /content/__MACOSX/frames/._original_frames
#    creating: /content/frames/train/
#   inflating: /content/__MACOSX/frames/._train
#    creating: /content/frames/validation/
#   inflating: /content/__MACOSX/frames/._validation
#    creating: /content/frames/test/TongueOut/
#   inflating: /content/__MACOSX/frames/test/._TongueOut
#    creating: /content/frames/test/HandsUp/
#   inflating: /content/__MACOSX/frames/test/._HandsUp
#    creating: /content/frames/test/Cry/
#   inflating: /content/__MACOSX/frames/test/._Cry
#    creating: /content/frames/test/Still/
#   inflating: /content/__MACOSX/frames/test/._Still
#    creating: /content/frames/test/Yawn/
#   inflating: /content/__MACOSX/frames/test/._Yawn
#    creating: /content/frames/original_frames/TongueOut/
#   inflating: /content/__MACOSX/frames/original_frames/._TongueOut
#    creating: /content/frames/original_frames/HandsUp/
#   inflating: /content/__MACOSX/frames/original_frames/._HandsUp
#    creating: /content/frames/original_frames/Cry/
#   inflating: /content/__MACOSX/frames/original_frames/._Cry
#    creating: /content/frames/original_frames/Still/
#   inflating: /content/__MACOSX/frames/original_frames/._Still
#    creating: /content/frames/original_frames/Yawn/
#   inflating: /content/__MACOSX/frames/original_frames/._Yawn
#    creating: /content/frames/train/TongueOut/
#   inflating: /content/__MACOSX/frames/train/._TongueOut
#    creating: /content/frames/train/HandsUp/
#   inflating: /content/__MACOSX/frames/train/._HandsUp
#    creating: /content/frames/train/Cry/
#   inflating: /content/__MACOSX/frames/train/._Cry
#    creating: /content/frames/train/Still/
#   inflating: /content/__MACOSX/frames/train/._Still
#    creating: /content/frames/train/Yawn/
#   inflating: /content/__MACOSX/frames/train/._Yawn
#    creating: /content/frames/validation/TongueOut/
#   inflating: /content/__MACOSX/frames/validation/._TongueOut
#    creating: /content/frames/validation/HandsUp/
#   inflating: /content/__MACOSX/frames/validation/._HandsUp
#    creating: /content/frames/validation/Cry/
#   inflating: /content/__MACOSX/frames/validation/._Cry
#    creating: /content/frames/validation/Still/
#   inflating: /content/__MACOSX/frames/validation/._Still
#    creating: /content/frames/validation/Yawn/
#   inflating: /content/__MACOSX/frames/validation/._Yawn
#   inflating: /content/frames/test/TongueOut/TongueOut25_f4.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut25_f4.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut27_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut27_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut27_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut27_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut27_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut27_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut25_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut25_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut25_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut25_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut25_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut25_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut27_f4.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut27_f4.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut5_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut5_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut5_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut5_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut5_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut5_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut5_f4.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut5_f4.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut24_f4.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut24_f4.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut24_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut24_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut24_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut24_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut24_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut24_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut4_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut4_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut32_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut32_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut41_f4.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut41_f4.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut20_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut20_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut4_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut4_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut32_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut32_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut20_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut20_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut20_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut20_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut32_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut32_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut4_f1.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut4_f1.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut41_f2.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut41_f2.jpg
#   inflating: /content/frames/test/TongueOut/TongueOut41_f3.jpg
#   inflating: /content/__MACOSX/frames/test/TongueOut/._TongueOut41_f3.jpg
#   inflating: /content/frames/test/TongueOut/TongueO
f3.jpg
#   inflating: /content/frames/validation/Cry/Cry13_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Cry/._Cry13_f2.jpg
#   inflating: /content/frames/validation/Cry/Cry13_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Cry/._Cry13_f1.jpg
#   inflating: /content/frames/validation/Cry/Cry40_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Cry/._Cry40_f4.jpg
#   inflating: /content/frames/validation/Cry/Cry40_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Cry/._Cry40_f1.jpg
#   inflating: /content/frames/validation/Cry/Cry40_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Cry/._Cry40_f3.jpg
#   inflating: /content/frames/validation/Cry/Cry40_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Cry/._Cry40_f2.jpg
#   inflating: /content/frames/validation/Still/Still4_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still4_f1.jpg
#   inflating: /content/frames/validation/Still/Still4_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still4_f3.jpg
#   inflating: /content/frames/validation/Still/Still4_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still4_f2.jpg
#   inflating: /content/frames/validation/Still/Still4_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still4_f4.jpg
#   inflating: /content/frames/validation/Still/Still2_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still2_f2.jpg
#   inflating: /content/frames/validation/Still/Still35_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still35_f1.jpg
#   inflating: /content/frames/validation/Still/Still2_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still2_f3.jpg
#   inflating: /content/frames/validation/Still/Still2_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still2_f1.jpg
#   inflating: /content/frames/validation/Still/Still35_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still35_f2.jpg
#   inflating: /content/frames/validation/Still/Still35_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still35_f3.jpg
#   inflating: /content/frames/validation/Still/Still2_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still2_f4.jpg
#   inflating: /content/frames/validation/Still/Still35_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still35_f4.jpg
#   inflating: /content/frames/validation/Still/Still14_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still14_f4.jpg
#   inflating: /content/frames/validation/Still/Still14_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still14_f3.jpg
#   inflating: /content/frames/validation/Still/Still14_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still14_f2.jpg
#   inflating: /content/frames/validation/Still/Still14_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still14_f1.jpg
#   inflating: /content/frames/validation/Still/Still10_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still10_f2.jpg
#   inflating: /content/frames/validation/Still/Still10_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still10_f3.jpg
#   inflating: /content/frames/validation/Still/Still1_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still1_f4.jpg
#   inflating: /content/frames/validation/Still/Still10_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still10_f1.jpg
#   inflating: /content/frames/validation/Still/Still10_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still10_f4.jpg
#   inflating: /content/frames/validation/Still/Still1_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still1_f3.jpg
#   inflating: /content/frames/validation/Still/Still1_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still1_f2.jpg
#   inflating: /content/frames/validation/Still/Still1_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Still/._Still1_f1.jpg
#   inflating: /content/frames/validation/Yawn/Yawn39_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn39_f1.jpg
#   inflating: /content/frames/validation/Yawn/Yawn39_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn39_f3.jpg
#   inflating: /content/frames/validation/Yawn/Yawn39_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn39_f2.jpg
#   inflating: /content/frames/validation/Yawn/Yawn39_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn39_f4.jpg
#   inflating: /content/frames/validation/Yawn/Yawn40_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn40_f4.jpg
#   inflating: /content/frames/validation/Yawn/Yawn40_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn40_f1.jpg
#   inflating: /content/frames/validation/Yawn/Yawn40_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn40_f2.jpg
#   inflating: /content/frames/validation/Yawn/Yawn40_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn40_f3.jpg
#   inflating: /content/frames/validation/Yawn/Yawn28_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn28_f4.jpg
#   inflating: /content/frames/validation/Yawn/Yawn28_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn28_f1.jpg
#   inflating: /content/frames/validation/Yawn/Yawn28_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn28_f2.jpg
#   inflating: /content/frames/validation/Yawn/Yawn28_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn28_f3.jpg
#   inflating: /content/frames/validation/Yawn/Yawn18_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn18_f4.jpg
#   inflating: /content/frames/validation/Yawn/Yawn22_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn22_f4.jpg
#   inflating: /content/frames/validation/Yawn/Yawn30_f4.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn30_f4.jpg
#   inflating: /content/frames/validation/Yawn/Yawn30_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn30_f3.jpg
#   inflating: /content/frames/validation/Yawn/Yawn18_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn18_f2.jpg
#   inflating: /content/frames/validation/Yawn/Yawn22_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn22_f3.jpg
#   inflating: /content/frames/validation/Yawn/Yawn22_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn22_f2.jpg
#   inflating: /content/frames/validation/Yawn/Yawn18_f3.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn18_f3.jpg
#   inflating: /content/frames/validation/Yawn/Yawn30_f2.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn30_f2.jpg
#   inflating: /content/frames/validation/Yawn/Yawn18_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn18_f1.jpg
#   inflating: /content/frames/validation/Yawn/Yawn22_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn22_f1.jpg
#   inflating: /content/frames/validation/Yawn/Yawn30_f1.jpg
#   inflating: /content/__MACOSX/frames/validation/Yawn/._Yawn30_f1.jpg

# %%
# !ls /content/frames/
# Out:
# original_frames  test  train  validation

# %%
import os
from pathlib import Path

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models

print("PyTorch version:", torch.__version__)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
# Out:
# PyTorch version: 2.9.0+cu126
# Using device: cuda

# %%
from pathlib import Path

DATA_DIR = Path("/content/frames")

print("Root frames folder:", DATA_DIR)
print("Subfolders:", list(p.name for p in DATA_DIR.iterdir()))
print("Train classes:", os.listdir(DATA_DIR / "train"))
print("Val classes:", os.listdir(DATA_DIR / "validation"))
print("Test classes:", os.listdir(DATA_DIR / "test"))
# Out:
# Root frames folder: /content/frames
# Subfolders: ['train', 'validation', 'test', '.DS_Store', 'original_frames']
# Train classes: ['Still', 'Cry', 'TongueOut', 'Yawn', 'HandsUp']
# Val classes: ['Still', 'Cry', 'TongueOut', 'Yawn', 'HandsUp']
# Test classes: ['Still', 'Cry', 'TongueOut', 'Yawn', 'HandsUp']

# %%
from torchvision import transforms, datasets
from torch.utils.data import DataLoader

BATCH_SIZE = 32
IMG_SIZE = 224
NUM_CLASSES = 5

## Data Transformations
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    ),
])

val_test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    ),
])

train_dir = DATA_DIR / "train"
val_dir   = DATA_DIR / "validation"
test_dir  = DATA_DIR / "test"

train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
val_dataset   = datasets.ImageFolder(root=val_dir, transform=val_test_transform)
test_dataset  = datasets.ImageFolder(root=test_dir, transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

print("Class to index mapping:", train_dataset.class_to_idx)
idx_to_class = {v:k for k,v in train_dataset.class_to_idx.items()}
print("Train size:", len(train_dataset))
print("Val size:", len(val_dataset))
print("Test size:", len(test_dataset))
# Out:
# Class to index mapping: {'Cry': 0, 'HandsUp': 1, 'Still': 2, 'TongueOut': 3, 'Yawn': 4}
# Train size: 596
# Val size: 124
# Test size: 144

# %%
from torchvision import models

# Load ResNet18
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)


in_features = model.fc.in_features
model.fc = nn.Linear(in_features, NUM_CLASSES)

model = model.to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)

print("Model ready.")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 56.9MB/s]
# Model ready.

# %%
#one epoch functions
def train_one_epoch(epoch, model, loader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    running_corrects = 0
    total = 0

    for images, labels in loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        _, preds = torch.max(outputs, 1)
        running_loss += loss.item() * images.size(0)
        running_corrects += (preds == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = running_corrects / total
    print(f"Epoch {epoch}: TRAIN   Loss={epoch_loss:.4f}  Acc={epoch_acc:.4f}")
    return epoch_loss, epoch_acc


def evaluate(model, loader, criterion, device, split_name="VAL"):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    total = 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item() * images.size(0)
            running_corrects += (preds == labels).sum().item()
            total += labels.size(0)

    loss = running_loss / total
    acc = running_corrects / total
    print(f"{split_name}: Loss={loss:.4f}  Acc={acc:.4f}")
    return loss, acc

# %%
train_loss_history = []
train_acc_history = []
val_loss_history = []
val_acc_history = []

# %%
## Run with epochs of 15 and saves the best
NUM_EPOCHS = 15
best_val_acc = 0.0
best_model_path = "/content/best_resnet18_emotes.pth"
PATIENCE = 5
epochs_without_improvement = 0

for epoch in range(1, NUM_EPOCHS + 1):
    train_loss, train_acc = train_one_epoch(epoch, model, train_loader, optimizer, criterion, DEVICE)
    val_loss, val_acc = evaluate(model, val_loader, criterion, DEVICE, "VAL")

    train_loss_history.append(train_loss)
    train_acc_history.append(train_acc)
    val_loss_history.append(val_loss)
    val_acc_history.append(val_acc)


    # Save best model by validation accuracy
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        epochs_without_improvement = 0
        torch.save(model.state_dict(), best_model_path)
        print(f"Saved new best model (val_acc={best_val_acc:.4f})")
    else:
        epochs_without_improvement += 1


    if epochs_without_improvement >= PATIENCE:
        print(f"Early stopping triggered at epoch {epoch}.")
        break

print("Training finished. Best VAL accuracy:", best_val_acc)
# Out:
# Epoch 1: TRAIN   Loss=0.0784  Acc=0.9765
# VAL: Loss=0.1906  Acc=0.9274
# Saved new best model (val_acc=0.9274)
# Epoch 2: TRAIN   Loss=0.0637  Acc=0.9782
# VAL: Loss=0.1461  Acc=0.9435
# Saved new best model (val_acc=0.9435)
# Epoch 3: TRAIN   Loss=0.0423  Acc=0.9866
# VAL: Loss=0.0734  Acc=0.9758
# Saved new best model (val_acc=0.9758)
# Epoch 4: TRAIN   Loss=0.0271  Acc=0.9950
# VAL: Loss=0.0746  Acc=0.9839
# Saved new best model (val_acc=0.9839)
# Epoch 5: TRAIN   Loss=0.0271  Acc=0.9933
# VAL: Loss=0.1349  Acc=0.9516
# Epoch 6: TRAIN   Loss=0.0227  Acc=0.9966
# VAL: Loss=0.0757  Acc=0.9677
# Epoch 7: TRAIN   Loss=0.0253  Acc=0.9916
# VAL: Loss=0.1111  Acc=0.9758
# Epoch 8: TRAIN   Loss=0.0168  Acc=0.9950
# VAL: Loss=0.0917  Acc=0.9597
# Epoch 9: TRAIN   Loss=0.0169  Acc=0.9966
# VAL: Loss=0.0510  Acc=0.9758
# Early stopping triggered at epoch 9.
# Training finished. Best VAL accuracy: 0.9838709677419355

# %%
if os.path.exists(best_model_path):
    model.load_state_dict(torch.load(best_model_path, map_location=DEVICE))
    print("Loaded best model from disk.")

# Final test evaluation
test_loss, test_acc = evaluate(model, test_loader, criterion, DEVICE, split_name="TEST")
print("Final TEST accuracy:", test_acc)
# Out:
# Loaded best model from disk.
# TEST: Loss=0.2154  Acc=0.9444
# Final TEST accuracy: 0.9444444444444444

# %%
drive_save_path = "/content/drive/MyDrive/DS340/best_resnet18_emotes.pth"
# !cp /content/best_resnet18_emotes.pth "$drive_save_path"
print("Saved model to:", drive_save_path)
# Out:
# Saved model to: /content/drive/MyDrive/DS340/best_resnet18_emotes.pth

# %% [markdown]
# ## Graphs

# %%
import matplotlib.pyplot as plt


epochs = range(1, len(train_acc_history) + 1)

plt.figure(figsize=(7,5))
plt.plot(epochs, train_acc_history, label="Train Accuracy")
plt.plot(epochs, val_acc_history, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import torch.nn.functional as F

all_labels = []
all_preds  = []

model.eval()
with torch.no_grad():
    for imgs, labels in test_loader:
        imgs = imgs.to(DEVICE)
        labels = labels.to(DEVICE)

        outputs = model(imgs)
        probs = F.softmax(outputs, dim=1)
        _, preds = torch.max(probs, 1)

        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

all_labels = np.array(all_labels)
all_preds  = np.array(all_preds)

print("Labels shape:", all_labels.shape)
print("Preds shape:", all_preds.shape)
# Out:
# Labels shape: (144,)
# Preds shape: (144,)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


labels_list = list(range(NUM_CLASSES))

cm = confusion_matrix(all_labels, all_preds, labels=labels_list)

cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)

class_names = [idx_to_class[i] for i in labels_list]

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Normalized Confusion Matrix (per actual class)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix (Actual Magnitudes)")
plt.tight_layout()
plt.show()
